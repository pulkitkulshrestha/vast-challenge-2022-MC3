# %%
import pandas as pd
df = pd.read_csv("../Data/employer_salary_emp_count&p2.csv")

# %%
# df = data.sort_values(['employerId', 'week'],ignore_index=True)

# %%
# df = data.sort_values(['employerId', 'week', 'employeeCount'], ascending=[True, True, False])
# df = df.groupby(['employerId', 'week']).apply(lambda x: x.loc[x['employeeCount'].idxmax()]).reset_index(drop=True)
# df
# Out:
#     week  region  employerId  Salary paid  employeeCount
# 0      1       1           1         8973             85
# 1      2       1           1        10208            129
# 2      3       1           1        23610            130
# 3      4       1           1         9441             79
# 4      5       1           1        18519            117
# 5      6       1           1         6217            144
# 6      7       1           1        12994            150
# 7      8       1           1        16063             82
# 8      9       1           1        19656            148
# 9     10       1           1        19396             74
# 10     1       2           2        23306             57
# 11     2       2           2        11550            139
# 12     3       2           2        21622             86
# 13     4       2           2        11600            131
# 14     5       2           2         8701            138
# ...

# %%
df.size
len(df)
# Out:
# 16126

# %%
df["prevCount"] = 0
i = 0
while i < len(df):
    for j in range(df["week"].max()):
        if(i >= len(df)):
            break
        if(df.loc[i,"week"]!=1): # skip first for each empolyer 
#             print(df.loc[i-1]["participant_count"])
            df.at[i, "prevCount"] = df.at[i-1, "participant_count"]        
        i+= 1;
    
df
# Out:
#        employerId  week  total_wages  participant_count  prevCount
# 0             379     1  3563.988527                  1          0
# 1             379     2   888.705334                  1          1
# 2             379     3   888.705334                  1          1
# 3             379     4   888.705334                  1          1
# 4             379     5   888.705334                  1          1
# ...           ...   ...          ...                ...        ...
# 16121        1797    61   400.000000                  1          1
# 16122        1797    62   400.000000                  1          1
# 16123        1797    63   400.000000                  1          1
# 16124        1797    64   400.000000                  1          1
# 16125        1797    65   160.000000                  1          1
#
# [16126 rows x 5 columns]

# %%
df.head(70)
# Out:
#     employerId  week   total_wages  participant_count  prevCount
# 0          379     1   3563.988527                  1          0
# 1          379     2    888.705334                  1          1
# 2          379     3    888.705334                  1          1
# 3          379     4    888.705334                  1          1
# 4          379     5    888.705334                  1          1
# ..         ...   ...           ...                ...        ...
# 65         381     1  12380.031550                  4          0
# 66         381     2   2960.344603                  4          4
# 67         381     3   2960.344603                  4          4
# 68         381     4   2960.344603                  4          4
# 69         381     5   2960.344603                  4          4
#
# [70 rows x 5 columns]

# %%
df.to_csv("../Data/employer_salary_emp_count&p2.csv", index=False)
